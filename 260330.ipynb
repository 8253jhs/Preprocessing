# %%
A = "안녕하세요 지금은 데이터 전처리 수업 시간입니다."

# %%
A[0:5]
# Out:
# '안녕하세요'

# %%
A[-1]
# Out:
# '.'

# %%
A[-5:]
# Out:
# '간입니다.'

# %%
A[-6:-4]
# Out:
# '시간'

# %%
A[21:23]
# Out:
# '시간'

# %%
A = "당신의 영어 성적은 {}점 입니다. 그리고 수학 성적은 {}점 입니다."
A.format(90, 80)
# Out:
# '당신의 영어 성적은 90점 입니다. 그리고 수학 성적은 80점 입니다.'

# %%
print(("{:.2f}, {:.5f}").format(3.141592, 3.1415926535))
# Out:
# 3.14, 3.14159

# %%
url = "https://www.youtube.com/"
str = url.replace("https://", "")
print(str)
# Out:
# www.youtube.com/

# %%
url = "https://www.youtube.com/"
str = url.replace("youtube", "naver")
print(str)
# Out:
# https://www.naver.com/

# %%
A = ["독고영재, 50", "김철수, 30"]
type(A[0])
# Out:
# str

# %%
A[0][:4]
# Out:
# '독고영재'

# %%
a = "독고영재, 50"
b = "김철수, 30"

# %%
a.index(",")
# Out:
# 4

# %%
a[:a.index(",")]
# Out:
# '독고영재'

# %%
b[:b.index(",")]
# Out:
# '김철수'

# %%
a = ["독고영재, 50", "김철수, 30"]
b = ["김철수, 20", "김영희, 25"]

# %%
a[0][:a[0].index(",")]
# Out:
# '독고영재'

# %%
b[1][:b[1].index(",")]
# Out:
# '김영희'

# %%
a = ["hi", 10, "80", "김철수", 50, 50.6]
a.append(50)

# %%
a
# Out:
# ['hi', 10, '80', '김철수', 50, 50.6, 50]

# %%
a.pop(1)
# Out:
# 10

# %%
a.index(50)
# Out:
# 3

# %%
b = a.index("80")
a.pop(b)
# Out:
# '80'

# %%
a
# Out:
# ['hi', '김철수', 50, 50.6, 50]

# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4])
a = np.append(a, [4, 5])

# %%
a
# Out:
# array([1, 2, 3, 4, 4, 5])

# %%
a = np.insert(a, 1, [7, 8])

# %%
a
# Out:
# array([1, 7, 8, 2, 3, 4, 4, 5])

# %%
a = np.array([1, 2, 3, 4, 5])

# %%
a = np.delete(a, [1, 3])

# %%
a
# Out:
# array([1, 3, 5])

# %%
a[a <= 4]
# Out:
# array([1, 2, 3, 4])

# %%
a[a != 4]
# Out:
# array([1, 2, 3, 5])

# %%
array1 = np.array([[1, 2], [3, 4]])
array2 = np.array([[5, 6], [7, 8]])

# %%
merged_array = np.vstack((array1, array2))
print(merged_array)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]
#  [7 8]]

# %%
merged_array = np.hstack((array1, array2))
print(merged_array)
# Out:
# [[1 2 5 6]
#  [3 4 7 8]]

# %%
A = {1 : "김철수", 20 : "박영희"}

# %%
A[1]
# Out:
# '김철수'

# %%
A[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 A[2]
#
# KeyError: 2

# %%
A[20]
# Out:
# '박영희'

# %%
A.get(1)
# Out:
# '김철수'

# %%
A.get(2)

# %%
A={"1-A" : "김철수", "20-B" : "박영희"}
A["2-A"] = "영재"
del A["20-B"]

# %%
A
# Out:
# {'1-A': '김철수', '2-A': '영재'}

# %%
A = {
    "1-A" : [1, 2, 3, 4, 5],
    "20-B" : ["A", "B", "C", "D", "E"]
}

# %%
A
# Out:
# {'1-A': [1, 2, 3, 4, 5], '20-B': ['A', 'B', 'C', 'D', 'E']}

# %%
import numpy as np

# %%
A = [10, 20, 30, [1, 2, 3]]
A[3]
# Out:
# [1, 2, 3]

# %%
math = [20, 30, 40, 50, 60]
eng = [50, 70, 50, 60, 90]

# %%
C1 = "https://www.youtube.com/"
C2 = C1.replace("https://", "")
C3 = C2.replace("youtube", "naver")
C4 = C3.replace("/", "")
print(C4)
# Out:
# www.naver.com

# %%
math1 = ((int(math[0]) + int(math[1]) + int(math[2]) + int(math[3]) + int(math[4]))
         // 5)
math1
# Out:
# 40

# %%
D = np.array([1, 2, 100, 4, 5, 900])
D = np.delete(D, [2, -1])
D
# Out:
# array([1, 2, 4, 5])

# %%
E = {
    "math" : [20, 30, 40, 50, 60],
    "eng" : [50, 70, 50, 60, 90]
}

# %%
(E["math"][0]) + (E["eng"][2])
# Out:
# 70
