# %%
import numpy as np

# %%
import pandas as pd

# %%
patient = pd.read_csv("patient_3.csv", encoding='cp949')

# %%
patient
# Out:
#            연구번호        입실일자      입실시각                           검사코드NM  \
# 0    1219300234  2021-02-20  13:50:00        pO2 (Qn)[EM],Artery blood
# 1    1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 2    1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 3    1219300234  2021-02-20  13:50:00        pO2 (Qn)[EM],Artery blood
# 4    1219300234  2021-02-20  13:50:00        pO2 (Qn)[EM],Artery blood
# ..          ...         ...       ...                              ...
# 229  1219281863  2021-02-20  19:35:00        pO2 (Qn)[EM],Artery blood
# 230  1219281863  2021-02-20  19:35:00        pO2 (Qn)[EM],Artery blood
# 231  1219281863  2021-02-20  19:35:00        pO2 (Qn)[EM],Artery blood
# 232  1219281863  2021-02-20  19:35:00  O2 saturation (Qn),Artery blood
# 233  1219281863  2021-02-20  19:35:00  O2 saturation (Qn),Artery blood
#
#      검사결과값(숫자)  기준치상한값  기준치하한값  검사나이        퇴실일자      퇴실시각   환자생년월 성별코드  \
# ...

# %%
trans1 = pd.read_csv("trans_1.csv", encoding='cp949')

# %%
trans2 = pd.read_csv("trans_2.csv", encoding='cp949')

# %%
trans1
# Out:
#               연구번호        입실일자      입실시각                           검사코드NM  \
# 0       1219300234  2021-02-20  13:50:00    Bicarbonate (Qn),Artery blood
# 1       1219300234  2021-02-20  13:50:00        pO2 (Qn)[EM],Artery blood
# 2       1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 3       1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 4       1219300234  2021-02-20  13:50:00       pCO2 (Qn)[EM],Artery blood
# ...            ...         ...       ...                              ...
# 464314  1169043575  2020-05-19  18:00:00        pO2 (Qn)[EM],Artery blood
# 464315  1169043575  2020-05-19  18:00:00       pCO2 (Qn)[EM],Artery blood
# 464316  1169043575  2020-05-19  18:00:00         Glucose (Qn)[POCT],Blood
# 464317  1169043575  2020-05-19  18:00:00         Glucose (Qn)[POCT],Blood
# 464318  1169043575  2020-05-19  18:00:00    Bicarbonate (Qn),Artery blood
#
#         검사결과값(숫자)  기준치상한값  기준치하한값  검사나이        접수일자 접수시각        퇴실일자  \
# ...

# %%
trans2
# Out:
#               연구번호        입실일자      입실시각                           검사코드NM  \
# 0       1219300234  2021-02-20  13:50:00       pCO2 (Qn)[EM],Artery blood
# 1       1219300234  2021-02-20  13:50:00        pO2 (Qn)[EM],Artery blood
# 2       1219300234  2021-02-20  13:50:00        pO2 (Qn)[EM],Artery blood
# 3       1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 4       1219300234  2021-02-20  13:50:00       pCO2 (Qn)[EM],Artery blood
# ...            ...         ...       ...                              ...
# 188141  1169043575  2020-05-19  18:00:00        pO2 (Qn)[EM],Artery blood
# 188142  1169043575  2020-05-19  18:00:00        pO2 (Qn)[EM],Artery blood
# 188143  1169043575  2020-05-19  18:00:00        pO2 (Qn)[EM],Artery blood
# 188144  1169043575  2020-05-19  18:00:00  O2 saturation (Qn),Artery blood
# 188145  1169043575  2020-05-19  18:00:00  O2 saturation (Qn),Artery blood
#
#         검사결과값(숫자)  기준치상한값  기준치하한값  검사나이        접수일자 접수시각        퇴실일자  \
# ...

# %%
trans = pd.concat([trans1, trans2], axis=0)

# %%
trans
# Out:
#               연구번호        입실일자      입실시각                           검사코드NM  \
# 0       1219300234  2021-02-20  13:50:00    Bicarbonate (Qn),Artery blood
# 1       1219300234  2021-02-20  13:50:00        pO2 (Qn)[EM],Artery blood
# 2       1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 3       1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 4       1219300234  2021-02-20  13:50:00       pCO2 (Qn)[EM],Artery blood
# ...            ...         ...       ...                              ...
# 188141  1169043575  2020-05-19  18:00:00        pO2 (Qn)[EM],Artery blood
# 188142  1169043575  2020-05-19  18:00:00        pO2 (Qn)[EM],Artery blood
# 188143  1169043575  2020-05-19  18:00:00        pO2 (Qn)[EM],Artery blood
# 188144  1169043575  2020-05-19  18:00:00  O2 saturation (Qn),Artery blood
# 188145  1169043575  2020-05-19  18:00:00  O2 saturation (Qn),Artery blood
#
#         검사결과값(숫자)  기준치상한값  기준치하한값  검사나이        접수일자 접수시각        퇴실일자  \
# ...

# %%
trans = trans.drop(['접수일자', '접수시각'], axis=1)

# %%
trans
# Out:
#               연구번호        입실일자      입실시각                           검사코드NM  \
# 0       1219300234  2021-02-20  13:50:00    Bicarbonate (Qn),Artery blood
# 1       1219300234  2021-02-20  13:50:00        pO2 (Qn)[EM],Artery blood
# 2       1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 3       1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 4       1219300234  2021-02-20  13:50:00       pCO2 (Qn)[EM],Artery blood
# ...            ...         ...       ...                              ...
# 188141  1169043575  2020-05-19  18:00:00        pO2 (Qn)[EM],Artery blood
# 188142  1169043575  2020-05-19  18:00:00        pO2 (Qn)[EM],Artery blood
# 188143  1169043575  2020-05-19  18:00:00        pO2 (Qn)[EM],Artery blood
# 188144  1169043575  2020-05-19  18:00:00  O2 saturation (Qn),Artery blood
# 188145  1169043575  2020-05-19  18:00:00  O2 saturation (Qn),Artery blood
#
#         검사결과값(숫자)  기준치상한값  기준치하한값  검사나이        퇴실일자      퇴실시각   환자생년월 성별코드  \
# ...

# %%
patient
# Out:
#            연구번호        입실일자      입실시각                           검사코드NM  \
# 0    1219300234  2021-02-20  13:50:00        pO2 (Qn)[EM],Artery blood
# 1    1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 2    1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 3    1219300234  2021-02-20  13:50:00        pO2 (Qn)[EM],Artery blood
# 4    1219300234  2021-02-20  13:50:00        pO2 (Qn)[EM],Artery blood
# ..          ...         ...       ...                              ...
# 229  1219281863  2021-02-20  19:35:00        pO2 (Qn)[EM],Artery blood
# 230  1219281863  2021-02-20  19:35:00        pO2 (Qn)[EM],Artery blood
# 231  1219281863  2021-02-20  19:35:00        pO2 (Qn)[EM],Artery blood
# 232  1219281863  2021-02-20  19:35:00  O2 saturation (Qn),Artery blood
# 233  1219281863  2021-02-20  19:35:00  O2 saturation (Qn),Artery blood
#
#      검사결과값(숫자)  기준치상한값  기준치하한값  검사나이        퇴실일자      퇴실시각   환자생년월 성별코드  \
# ...

# %%
trans_1 = trans[(trans["환자ID"] == 12100234)]

# %%
trans_1
# Out:
#            연구번호        입실일자      입실시각                           검사코드NM  \
# 0    1219300234  2021-02-20  13:50:00    Bicarbonate (Qn),Artery blood
# 1    1219300234  2021-02-20  13:50:00        pO2 (Qn)[EM],Artery blood
# 2    1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 3    1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 4    1219300234  2021-02-20  13:50:00       pCO2 (Qn)[EM],Artery blood
# ..          ...         ...       ...                              ...
# 115  1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 116  1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 117  1219300234  2021-02-20  13:50:00       pCO2 (Qn)[EM],Artery blood
# 118  1219300234  2021-02-20  13:50:00       pCO2 (Qn)[EM],Artery blood
# 119  1219300234  2021-02-20  13:50:00       pCO2 (Qn)[EM],Artery blood
#
#      검사결과값(숫자)  기준치상한값  기준치하한값  검사나이        퇴실일자      퇴실시각   환자생년월 성별코드  \
# ...

# %%
trans_2 = trans[(trans["환자ID"] == 12181863)]

# %%
trans_2
# Out:
#            연구번호        입실일자      입실시각                           검사코드NM  \
# 369  1219281863  2021-02-20  19:35:00             Hct (Qn)[POCT],Blood
# 370  1219281863  2021-02-20  19:35:00             Hct (Qn)[POCT],Blood
# 371  1219281863  2021-02-20  19:35:00         Glucose (Qn)[POCT],Blood
# 372  1219281863  2021-02-20  19:35:00         Glucose (Qn)[POCT],Blood
# 373  1219281863  2021-02-20  19:35:00         Glucose (Qn)[POCT],Blood
# ..          ...         ...       ...                              ...
# 150  1219281863  2021-02-20  19:35:00       pCO2 (Qn)[EM],Artery blood
# 151  1219281863  2021-02-20  19:35:00        pO2 (Qn)[EM],Artery blood
# 152  1219281863  2021-02-20  19:35:00  O2 saturation (Qn),Artery blood
# 153  1219281863  2021-02-20  19:35:00       pCO2 (Qn)[EM],Artery blood
# 154  1219281863  2021-02-20  19:35:00  O2 saturation (Qn),Artery blood
#
#      검사결과값(숫자)  기준치상한값  기준치하한값 검사나이        퇴실일자      퇴실시각   환자생년월 성별코드  \
# ...

# %%
trans = pd.concat([trans_1, trans_2], axis=0)

# %%
trans_3 = trans[(trans["검사코드NM"] == 'O2 saturation (Qn),Artery blood')]

# %%
trans_4 = trans[(trans["검사코드NM"] == 'pO2 (Qn)[EM],Artery blood')]

# %%
trans_5 = trans[(trans["검사코드NM"] == 'Sodium (Qn)[POCT],Blood')]

# %%
trans = pd.concat([trans_3, trans_4, trans_5], axis=0)

# %%
trans
# Out:
#            연구번호        입실일자      입실시각                           검사코드NM  \
# 2    1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 3    1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 13   1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 17   1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 22   1219300234  2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# ..          ...         ...       ...                              ...
# 71   1219300234  2021-02-20  13:50:00          Sodium (Qn)[POCT],Blood
# 181  1219300234  2021-02-20  13:50:00          Sodium (Qn)[POCT],Blood
# 328  1219300234  2021-02-20  13:50:00          Sodium (Qn)[POCT],Blood
# 349  1219300234  2021-02-20  13:50:00          Sodium (Qn)[POCT],Blood
# 404  1219281863  2021-02-20  19:35:00          Sodium (Qn)[POCT],Blood
#
#      검사결과값(숫자)  기준치상한값  기준치하한값  검사나이        퇴실일자      퇴실시각   환자생년월 성별코드  \
# ...
